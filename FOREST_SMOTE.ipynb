# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import precision_score , recall_score
from imblearn.over_sampling import SMOTE 

data_df = pd.read_csv('NEW_dataset_csv.csv')
book=pd.read_csv('Book1.csv')
print(data_df.shape)
data_df.head()
# Out:
# (460846, 34)
# C:\Users\Sa\AppData\Local\Temp\ipykernel_15848\1878510035.py:12: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv('NEW_dataset_csv.csv')
#   record type  0_pre-RR  0_post-RR   0_pPeak   0_tPeak   0_rPeak   0_sPeak  \
# 0    I01    N       163        165  0.069610 -0.083281  0.614133 -0.392761
# 1    I01    N       165        166 -0.097030  0.597254 -0.078704 -0.078704
# 2    I01    N       166        102  0.109399  0.680528 -0.010649 -0.010649
# 3    I01  VEB       102        231  0.176376  0.256431 -0.101098 -0.707525
# 4    I01    N       231        165  0.585577  0.607461 -0.083499 -0.083499
#
#     0_qPeak  0_qrs_interval  ...   1_qPeak  1_qrs_interval  1_pq_interval  \
# 0  0.047159              15  ... -0.023370              14              3
# 1 -0.137781               3  ...  0.081637              15              5
# 2 -0.720620               6  ... -0.148539              33             13
# 3 -0.101098               4  ...  0.046898              21              9
# 4 -0.167858               3  ... -0.112552              32              5
#
#    1_qt_interval  1_st_interval  1_qrs_morph0  1_qrs_morph1  1_qrs_morph2  \
# 0             23              6     -0.023370     -0.011650      0.082608
# 1             27              7      0.081637      0.102992      0.191225
# 2             52              6     -0.148539     -0.060620      0.081080
# 3             34              4      0.046898      0.083728      0.279512
# 4             43              6     -0.112552      0.012989      0.091491
#
#    1_qrs_morph3  1_qrs_morph4
# 0      0.101373     -0.183387
# 1      0.217544     -0.068248
# 2      0.204400      0.335172
# 3      0.526785      0.450969
# 4      0.134004      0.265232
#
# [5 rows x 34 columns]

# %%
x_data = data_df.iloc[:, 2:]
y_label = data_df[['type']]
z_label = data_df[['type']]
z_label.value_counts()
y_label.replace(['VEB', 'SVEB', 'F', 'Q'], 'Arrhythmia', inplace=True)
y_label.replace(['N'], 'Normal', inplace=True)
# Out:
# C:\Users\Sa\AppData\Local\Temp\ipykernel_15848\1430154249.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_label.replace(['VEB', 'SVEB', 'F', 'Q'], 'Arrhythmia', inplace=True)
# C:\Users\Sa\AppData\Local\Temp\ipykernel_15848\1430154249.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y_label.replace(['N'], 'Normal', inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
Y = labelencoder.fit_transform(y_label)
# Out:
# C:\Users\Sa\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y = pd.DataFrame(Y)  
y.value_counts()
y
# Out:
#         0
# 0       1
# 1       1
# 2       1
# 3       0
# 4       1
# ...    ..
# 460841  1
# 460842  1
# 460843  1
# 460844  1
# 460845  0
#
# [460846 rows x 1 columns]

# %%
smote=SMOTE()
x_re,y_re = smote.fit_resample(x_data,y)
y_re.value_counts()
# Out:
# 0
# 0    405824
# 1    405824
# Name: count, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(x_re, y_re, random_state=101,test_size=0.3)

# %%
#### from sklearn import preprocessing
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_train_scaled = min_max_scaler.fit_transform(X_train)
X_test_scaled = min_max_scaler.transform(X_test)
print(min_max_scaler.scale_)

#x = x-xmin/xmax-xmin
# Out:
# [0.0004948  0.00047304 0.12481022 0.1271735  0.09160676 0.089344
#  0.10505125 0.00588235 0.00671141 0.00302115 0.00714286 0.10505125
#  0.10146786 0.08989194 0.09177522 0.08786043 0.0004948  0.00047304
#  0.10266912 0.10530541 0.13019377 0.10789525 0.10539906 0.00384615
#  0.00543478 0.00251256 0.00574713 0.10539906 0.11766062 0.12474112
#  0.13092419 0.12581481]

# %%
X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
from sklearn.ensemble import RandomForestClassifier

RAND = RandomForestClassifier(random_state=101, n_estimators=50)
RAND.fit(X_train_scaled_df, y_train)
# Out:
# C:\Users\Sa\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier(n_estimators=50, random_state=101)

# %%
from sklearn import metrics
y_pred = RAND.predict(X_test_scaled_df)
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
cm=confusion_matrix(y_test,y_pred)
# Out:
# Accuracy: 0.9901887102404567

# %%
cm
# Out:
# array([[120785,    823],
#        [  1566, 120321]], dtype=int64)

# %%
recall_score(y_test,y_pred,pos_label=0)
# Out:
# 0.9932323531346622

# %%
precision_score(y_test,y_pred,pos_label=0)
# Out:
# 0.9872007584735719

# %%
f1_score(y_test, y_pred)
# Out:
# 0.9901699783155236

# %%
from sklearn.metrics import cohen_kappa_score
cohen_kappa_score(y_test, y_pred)
# Out:
# 0.9803775319321801
